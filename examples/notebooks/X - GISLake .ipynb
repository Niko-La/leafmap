# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/giswqs/leafmap/blob/master/examples/notebooks/09_csv_to_points.ipynb)
# [![image](https://binder.pangeo.io/badge_logo.svg)](https://gishub.org/leafmap-pangeo)
#
# Uncomment the following line to install [leafmap](https://leafmap.org) if needed.

# %%
# !pip install leafmap

# %%
import os
import leafmap.leafmap as leafmap

#leafmap.update_package()

# %%
in_csv_1 = 'https://raw.githubusercontent.com/Niko-La/jupyter_equity_2020/main/world_cities.csv'
in_csv_2 = 'https://raw.githubusercontent.com/Niko-La/jupyter_equity_2020/main/GISLAKE%20-%20Sheet%201.csv'

# %%
df = leafmap.csv_to_pandas(in_csv_2)
of = leafmap.csv_to_pandas(in_csv_1)
of
# Out:
#         id            name country  latitude  longitude  population
# 0        1           Bombo     UGA   0.58330   32.53330       75000
# 1        2     Fort Portal     UGA   0.67100   30.27500       42670
# 2        3         Potenza     ITA  40.64200   15.79900       69060
# 3        4      Campobasso     ITA  41.56300   14.65600       50762
# 4        5           Aosta     ITA  45.73700    7.31500       34062
# ...    ...             ...     ...       ...        ...         ...
# 1244  1245  Rio de Janeiro     BRA -22.92502  -43.22502    11748000
# 1245  1246       Sao Paulo     BRA -23.55868  -46.62502    18845000
# 1246  1247          Sydney     AUS -33.92001  151.18518     4630000
# 1247  1248       Singapore     SGP   1.29303  103.85582     5183700
# 1248  1249       Hong Kong     CHN  22.30498  114.18501     7206000
#
# [1249 rows x 6 columns]

# %%
df.dropna(subset = ['longitude'], inplace=True)
df = df.reset_index(drop=True)
df
# Out:
#          ID                    FACILITY NAME  \
# 0    NH2048    RIVER GLEN HAVEN NURSING HOME
# 1    H11318                   CAREFREE LODGE
# 2    H21341  BETTER LIVING AT THOMPSON HOUSE
# 3    NH1324  DOWNSVIEW LONG TERM CARE CENTRE
# 4    NH1316              EXTENDICARE BAYVIEW
# ..      ...                              ...
# 188  NH1949     LAPOINTE-FISHER NURSING HOME
# 189  NM3324      MORRISTON PARK NURSING HOME
# 190  NH3526                  RIVERBEND PLACE
# 191  NH1910                   FOREST HEIGHTS
# 192  NH1959    SAUGEEN VALLEY NURSING CENTER
#
#                                       LICENSEE  \
# 0                       ATK Care Group Limited
# 1    Toronto Long-Term Care Homes And Services
# 2             Don Mills Foundation For Seniors
# 3      Downsview Long Term Care Centre Limited
# 4                    Extendicare (Canada) Inc.
# ..                                         ...
# 188      Lapointe-Fisher Nursing Home, Limited
# ...

# %%
df = df.loc[:, ['ID','latitude','longitude']]
df
# Out:
#          ID  latitude  longitude
# 0    NH2048  39.71946 -104.96492
# 1    H11318  43.78501  -79.39411
# 2    H21341  43.73246  -79.34667
# 3    NH1324  43.75118  -79.48559
# 4    NH1316  43.79340  -79.39067
# ..      ...       ...        ...
# 188  NH1949  43.56334  -80.25740
# 189  NM3324  43.43998  -80.12737
# 190  NH3526  43.37692  -80.32575
# 191  NH1910  43.42863  -80.52998
# 192  NH1959  43.97520  -80.73907
#
# [193 rows x 3 columns]

# %%
Map = leafmap.Map()
Map.add_xy_data(in_csv_1, x="longitude", y="latitude", layer_name="World")
Map
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
leafmap.split_map(left_layer="Esri.WorldTopoMap", right_layer="OpenTopoMap")
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
out_geojson = os.path.join(out_dir, 'world_cities.geojson')
leafmap.csv_to_geojson(in_csv, out_geojson)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-172e43866601> in <module>
# ----> 1 out_geojson = os.path.join(out_dir, 'world_cities.geojson')
#       2 leafmap.csv_to_geojson(in_csv, out_geojson)
#
# NameError: name 'out_dir' is not defined

# %%
# gdf = leafmap.csv_to_gdf(in_csv)
# gdf
